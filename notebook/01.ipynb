# %%
from torchvision.datasets import VOCSegmentation
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# 自动下载VOC2012数据集
train_dataset = VOCSegmentation(
    root='./data',  # 数据存储路径
    year='2012',
    image_set='train',  # 也可以是 'val', 'trainval'
    download=True,  # 自动下载
    transform=transforms.ToTensor()
)

val_dataset = VOCSegmentation(
    root='./data',
    year='2012',
    image_set='val',
    download=False,  # 已下载，不需要重复下载
    transform=transforms.ToTensor()
)

print(f"训练集大小: {len(train_dataset)}")
print(f"验证集大小: {len(val_dataset)}")

# 可视化一个样本
image, mask = train_dataset[0]
print(f"图像尺寸: {image.size()}")
print(f"掩码尺寸: {mask.size()}")

# 可视化
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.imshow(image.permute(1, 2, 0))
plt.title("原始图像")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(mask, cmap='tab20')
plt.title("分割掩码")
plt.axis('off')
plt.show()
# Out:
# Downloading http://host.robots.ox.ac.uk/pascal/VOC/voc2012/VOCtrainval_11-May-2012.tar to ./data\VOCtrainval_11-May-2012.tar
# 100%|██████████| 4.52k/4.52k [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 6
#       3 import matplotlib.pyplot as plt
#       5 # 自动下载VOC2012数据集
# ----> 6 train_dataset = VOCSegmentation(
#       7     root='./data',  # 数据存储路径
#       8     year='2012',
#       9     image_set='train',  # 也可以是 'val', 'trainval'
#      10     download=True,  # 自动下载
#      11     transform=transforms.ToTensor()
#      12 )
#      14 val_dataset = VOCSegmentation(
#      15     root='./data',
#      16     year='2012',
#    (...)
#      19     transform=transforms.ToTensor()
#      20 )
#      22 print(f"训练集大小: {len(train_dataset)}")
#
# File c:\Users\w\.conda\envs\machine_learning\lib\site-packages\torchvision\datasets\voc.py:98, in _VOCBase.__init__(self, root, year, image_set, download, transform, target_transform, transforms)
#      95 voc_root = os.path.join(self.root, base_dir)
#      97 if download:
# ---> 98     download_and_extract_archive(self.url, self.root, filename=self.filename, md5=self.md5)
#     100 if not os.path.isdir(voc_root):
#     101     raise RuntimeError("Dataset not found or corrupted. You can use download=True to download it")
#
# File c:\Users\w\.conda\envs\machine_learning\lib\site-packages\torchvision\datasets\utils.py:395, in download_and_extract_archive(url, download_root, extract_root, filename, md5, remove_finished)
#     392 if not filename:
#     393     filename = os.path.basename(url)
# --> 395 download_url(url, download_root, filename, md5)
#     397 archive = os.path.join(download_root, filename)
#     398 print(f"Extracting {archive} to {extract_root}")
#
# File c:\Users\w\.conda\envs\machine_learning\lib\site-packages\torchvision\datasets\utils.py:143, in download_url(url, root, filename, md5, max_redirect_hops)
#     141 # check integrity of downloaded file
#     142 if not check_integrity(fpath, md5):
# --> 143     raise RuntimeError("File not found or corrupted.")
#
# RuntimeError: File not found or corrupted.
